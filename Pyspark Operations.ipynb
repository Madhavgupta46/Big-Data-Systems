# %% [markdown]
# # Dataset Description
# Create a PySpark DataFrame with the following columns:
# employee_id (int)
# name (string)
# age (int)
# gender (string)
# department (string)
# role (string)
# salary (int)
# city (string)
# Create own sample data (minimum 15–20 records).

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sum, avg, max as spark_max, min as spark_min, count, countDistinct

# %%
# Create SparkSession
spark = SparkSession.builder.appName("EmployeeDataFrame").getOrCreate()

# %%
# Sample Employee Data (20 records)
employee_data= [
    (1, "Arjun Verma", 27, "Male", "IT", "Developer", 57000, "Delhi"),
    (2, "Sneha Iyer", 34, "Female", "HR", "Manager", 78000, "Chennai"),
    (3, "Rakesh Yadav", 39, "Male", "Finance", "Analyst", 62000, "UP"),
    (4, "Anjali Sharma", 26, "Female", "IT", "Tester", 51000, "Delhi"),
    (5, "Harshvardhan Singh", 37, "Male", "Marketing", "Manager", 82000, "Jaipur"),
    (6, "Preeti Chauhan", 30, "Female", "HR", "Executive", 47000, "Delhi"),
    (7, "Nikhil Aggarwal", 44, "Male", "Finance", "Manager", 92000, "Mumbai"),
    (8, "Simran Kaur", 28, "Female", "IT", "Developer", 61000, "Punjab"),
    (9, "Yash Malhotra", 31, "Male", "Sales", "Executive", 49000, "Delhi"),
    (10, "Komal Jain", 38, "Female", "Operations", "Manager", 74000, "Indore"),
    (11, "Aditya Raj", 25, "Male", "IT", "Developer", 56000, "Bihar"),
    (12, "Nisha Patil", 42, "Female", "Finance", "Analyst", 69000, "Pune"),
    (13, "Varun Khanna", 33, "Male", "Marketing", "Analyst", 53000, "Delhi"),
    (14, "Rekha Gupta", 29, "Female", "HR", "Executive", 48000, "Delhi"),
    (15, "Sanjay Malviya", 46, "Male", "IT", "Architect", 125000, "Bhopal"),
    (16, "Pallavi Sinha", 35, "Female", "Sales", "Manager", 87000, "Kolkata"),
    (17, "Deepak Kumar", 28, "Male", "Operations", "Executive", 51000, "UP"),
    (18, "Rashmi Desai", 37, "Female", "Finance", "Senior Analyst", 80000, "Mumbai"),
    (19, "Aman Tiwari", 24, "Male", "IT", "Intern", 32000, "Delhi"),
    (20, "Neelam Verma", 40, "Female", "Marketing", "Director", 115000, "Lucknow")
]

# Define schema columns
columns = ["employee_id", "name", "age", "gender", "department", "role", "salary", "city"]

# Create DataFrame
df = spark.createDataFrame(data=employee_data, schema=columns)
print("Original DataFrame:")
df.show()
# Out:
# Original DataFrame:
# +-----------+------------------+---+------+----------+--------------+------+-------+
# |employee_id|              name|age|gender|department|          role|salary|   city|
# +-----------+------------------+---+------+----------+--------------+------+-------+
# |          1|       Arjun Verma| 27|  Male|        IT|     Developer| 57000|  Delhi|
# |          2|        Sneha Iyer| 34|Female|        HR|       Manager| 78000|Chennai|
# |          3|      Rakesh Yadav| 39|  Male|   Finance|       Analyst| 62000|     UP|
# |          4|     Anjali Sharma| 26|Female|        IT|        Tester| 51000|  Delhi|
# |          5|Harshvardhan Singh| 37|  Male| Marketing|       Manager| 82000| Jaipur|
# |          6|    Preeti Chauhan| 30|Female|        HR|     Executive| 47000|  Delhi|
# |          7|   Nikhil Aggarwal| 44|  Male|   Finance|       Manager| 92000| Mumbai|
# |          8|       Simran Kaur| 28|Female|        IT|     Developer| 61000| Punjab|
# |          9|     Yash Malhotra| 31|  Male|     Sales|     Executive| 49000|  Delhi|
# |         10|        Komal Jain| 38|Female|Operations|       Manager| 74000| Indore|
# |         11|        Aditya Raj| 25|  Male|        IT|     Developer| 56000|  Bihar|
# |         12|       Nisha Patil| 42|Female|   Finance|       Analyst| 69000|   Pune|
# |         13|      Varun Khanna| 33|  Male| Marketing|       Analyst| 53000|  Delhi|
# |         14|       Rekha Gupta| 29|Female|        HR|     Executive| 48000|  Delhi|
# |         15|    Sanjay Malviya| 46|  Male|        IT|     Architect|125000| Bhopal|
# |         16|     Pallavi Sinha| 35|Female|     Sales|       Manager| 87000|Kolkata|
# |         17|      Deepak Kumar| 28|  Male|Operations|     Executive| 51000|     UP|
# |         18|      Rashmi Desai| 37|Female|   Finance|Senior Analyst| 80000| Mumbai|
# |         19|       Aman Tiwari| 24|  Male|        IT|        Intern| 32000|  Delhi|
# |         20|      Neelam Verma| 40|Female| Marketing|      Director|115000|Lucknow|
# +-----------+------------------+---+------+----------+--------------+------+-------+

# %% [markdown]
# # Operations
# 1.Filter employees with salary greater than 50,000.
#
# 2. Filter employees whose age is above 30.
#
# 3. Count total number of employees.
#
# 4. Show all employees from a specific city (e.g., "Delhi").
#
# 5. Select only name and salary columns.

# %%
## 1. Operations

#1. Filter employees with salary > 50,000
print("\n1. Employees with salary > 50,000:")
df.filter(df.salary > 50000).show()
# Out:
# 1. Employees with salary > 50,000:
# +-----------+------------------+---+------+----------+--------------+------+-------+
# |employee_id|              name|age|gender|department|          role|salary|   city|
# +-----------+------------------+---+------+----------+--------------+------+-------+
# |          1|       Arjun Verma| 27|  Male|        IT|     Developer| 57000|  Delhi|
# |          2|        Sneha Iyer| 34|Female|        HR|       Manager| 78000|Chennai|
# |          3|      Rakesh Yadav| 39|  Male|   Finance|       Analyst| 62000|     UP|
# |          4|     Anjali Sharma| 26|Female|        IT|        Tester| 51000|  Delhi|
# |          5|Harshvardhan Singh| 37|  Male| Marketing|       Manager| 82000| Jaipur|
# |          7|   Nikhil Aggarwal| 44|  Male|   Finance|       Manager| 92000| Mumbai|
# |          8|       Simran Kaur| 28|Female|        IT|     Developer| 61000| Punjab|
# |         10|        Komal Jain| 38|Female|Operations|       Manager| 74000| Indore|
# |         11|        Aditya Raj| 25|  Male|        IT|     Developer| 56000|  Bihar|
# |         12|       Nisha Patil| 42|Female|   Finance|       Analyst| 69000|   Pune|
# |         13|      Varun Khanna| 33|  Male| Marketing|       Analyst| 53000|  Delhi|
# |         15|    Sanjay Malviya| 46|  Male|        IT|     Architect|125000| Bhopal|
# |         16|     Pallavi Sinha| 35|Female|     Sales|       Manager| 87000|Kolkata|
# |         17|      Deepak Kumar| 28|  Male|Operations|     Executive| 51000|     UP|
# |         18|      Rashmi Desai| 37|Female|   Finance|Senior Analyst| 80000| Mumbai|
# |         20|      Neelam Verma| 40|Female| Marketing|      Director|115000|Lucknow|
# +-----------+------------------+---+------+----------+--------------+------+-------+

# %%
#2. Filter employees with age > 30
print("\n2. Employees with age > 30:")
df.filter(df.age > 30).show()
# Out:
# 2. Employees with age > 30:
# +-----------+------------------+---+------+----------+--------------+------+-------+
# |employee_id|              name|age|gender|department|          role|salary|   city|
# +-----------+------------------+---+------+----------+--------------+------+-------+
# |          2|        Sneha Iyer| 34|Female|        HR|       Manager| 78000|Chennai|
# |          3|      Rakesh Yadav| 39|  Male|   Finance|       Analyst| 62000|     UP|
# |          5|Harshvardhan Singh| 37|  Male| Marketing|       Manager| 82000| Jaipur|
# |          7|   Nikhil Aggarwal| 44|  Male|   Finance|       Manager| 92000| Mumbai|
# |          9|     Yash Malhotra| 31|  Male|     Sales|     Executive| 49000|  Delhi|
# |         10|        Komal Jain| 38|Female|Operations|       Manager| 74000| Indore|
# |         12|       Nisha Patil| 42|Female|   Finance|       Analyst| 69000|   Pune|
# |         13|      Varun Khanna| 33|  Male| Marketing|       Analyst| 53000|  Delhi|
# |         15|    Sanjay Malviya| 46|  Male|        IT|     Architect|125000| Bhopal|
# |         16|     Pallavi Sinha| 35|Female|     Sales|       Manager| 87000|Kolkata|
# |         18|      Rashmi Desai| 37|Female|   Finance|Senior Analyst| 80000| Mumbai|
# |         20|      Neelam Verma| 40|Female| Marketing|      Director|115000|Lucknow|
# +-----------+------------------+---+------+----------+--------------+------+-------+

# %%
#3. Count total number of employees
total_employees = df.count()
print(f"\n3. Total employees: {total_employees}")
# Out:
# 3. Total employees: 20

# %%
#4. Show employees from Delhi
print("\n4. Employees from Delhi:")
df.filter(df.city == "Delhi").show()
# Out:
# 4. Employees from Delhi:
# +-----------+--------------+---+------+----------+---------+------+-----+
# |employee_id|          name|age|gender|department|     role|salary| city|
# +-----------+--------------+---+------+----------+---------+------+-----+
# |          1|   Arjun Verma| 27|  Male|        IT|Developer| 57000|Delhi|
# |          4| Anjali Sharma| 26|Female|        IT|   Tester| 51000|Delhi|
# |          6|Preeti Chauhan| 30|Female|        HR|Executive| 47000|Delhi|
# |          9| Yash Malhotra| 31|  Male|     Sales|Executive| 49000|Delhi|
# |         13|  Varun Khanna| 33|  Male| Marketing|  Analyst| 53000|Delhi|
# |         14|   Rekha Gupta| 29|Female|        HR|Executive| 48000|Delhi|
# |         19|   Aman Tiwari| 24|  Male|        IT|   Intern| 32000|Delhi|
# +-----------+--------------+---+------+----------+---------+------+-----+

# %%
#5. Select only name and salary columns
print("\n5. Name and Salary columns:")
df.select("name", "salary").show()
# Out:
# 5. Name and Salary columns:
# +------------------+------+
# |              name|salary|
# +------------------+------+
# |       Arjun Verma| 57000|
# |        Sneha Iyer| 78000|
# |      Rakesh Yadav| 62000|
# |     Anjali Sharma| 51000|
# |Harshvardhan Singh| 82000|
# |    Preeti Chauhan| 47000|
# |   Nikhil Aggarwal| 92000|
# |       Simran Kaur| 61000|
# |     Yash Malhotra| 49000|
# |        Komal Jain| 74000|
# |        Aditya Raj| 56000|
# |       Nisha Patil| 69000|
# |      Varun Khanna| 53000|
# |       Rekha Gupta| 48000|
# |    Sanjay Malviya|125000|
# |     Pallavi Sinha| 87000|
# |      Deepak Kumar| 51000|
# |      Rashmi Desai| 80000|
# |       Aman Tiwari| 32000|
# |      Neelam Verma|115000|
# +------------------+------+

# %% [markdown]
# # GroupBy Operations
# 1. Group by department and count employees in each department.
#
# 2. Find total salary per department.
# 3. Find average salary per department.
# 4. Group by city and find max salary.
# 5. Group by department and gender and count employees.

# %%
#6. Group by department and count employees
print("\n6. Employees count by department:")
df.groupBy("department").count().show()
# Out:
# 6. Employees count by department:
# +----------+-----+
# |department|count|
# +----------+-----+
# |     Sales|    2|
# |        HR|    3|
# |   Finance|    4|
# | Marketing|    3|
# |        IT|    6|
# |Operations|    2|
# +----------+-----+

# %%
#7. Total salary per department
print("\n7. Total salary per department:")
df.groupBy("department").agg(sum("salary").alias("total_salary")).show()
# Out:
# 7. Total salary per department:
# +----------+------------+
# |department|total_salary|
# +----------+------------+
# |     Sales|      136000|
# |        HR|      173000|
# |   Finance|      303000|
# | Marketing|      250000|
# |        IT|      382000|
# |Operations|      125000|
# +----------+------------+

# %%
#8. Average salary per department
print("\n8. Average salary per department:")
df.groupBy("department").agg(avg("salary").alias("avg_salary")).show()
# Out:
# 8. Average salary per department:
# +----------+------------------+
# |department|        avg_salary|
# +----------+------------------+
# |     Sales|           68000.0|
# |        HR|57666.666666666664|
# |   Finance|           75750.0|
# | Marketing| 83333.33333333333|
# |        IT|63666.666666666664|
# |Operations|           62500.0|
# +----------+------------------+

# %%
#9. Max salary by city
print("\n9. Max salary by city:")
df.groupBy("city").agg(spark_max("salary").alias("max_salary")).show()
# Out:
# 9. Max salary by city:
# +-------+----------+
# |   city|max_salary|
# +-------+----------+
# | Punjab|     61000|
# |Chennai|     78000|
# | Mumbai|     92000|
# |     UP|     62000|
# |  Delhi|     57000|
# | Indore|     74000|
# | Jaipur|     82000|
# |Lucknow|    115000|
# |Kolkata|     87000|
# |   Pune|     69000|
# | Bhopal|    125000|
# |  Bihar|     56000|
# +-------+----------+

# %%
#10. Group by department and gender, count employees
print("\n10. Employee count by department and gender:")
df.groupBy("department", "gender").count().show()
# Out:
# 10. Employee count by department and gender:
# +----------+------+-----+
# |department|gender|count|
# +----------+------+-----+
# |        IT|Female|    2|
# |Operations|Female|    1|
# |     Sales|  Male|    1|
# | Marketing|  Male|    2|
# |        IT|  Male|    4|
# |   Finance|  Male|    2|
# |        HR|Female|    3|
# | Marketing|Female|    1|
# |Operations|  Male|    1|
# |   Finance|Female|    2|
# |     Sales|Female|    1|
# +----------+------+-----+

# %% [markdown]
# # Multiple Aggregation
# 1. Perform multiple aggregations on salary per department:
# 2. sum
# 3. average
# 4. max
# 5. min
# 6. Rename all aggregated columns appropriately.
# 7. Group by department and role, then calculate:
# 8. total salary
# 9. average salary
# 10. employee count
# 11. Count distinct roles in each department.
# 12. Find the top 3 departments with the highest total salary.

# %%
#11. Sum
print("\n11.1 SUM salary per department:")
df.groupBy("department").agg(sum("salary").alias("total_salary")).show()
# Out:
# 11.1 SUM salary per department:
# +----------+------------+
# |department|total_salary|
# +----------+------------+
# |     Sales|      136000|
# |        HR|      173000|
# |   Finance|      303000|
# | Marketing|      250000|
# |        IT|      382000|
# |Operations|      125000|
# +----------+------------+

# %%
#12. Average Aggregation Only
print("\n11.2 AVERAGE salary per department:")
df.groupBy("department").agg(avg("salary").alias("avg_salary")).show()
# Out:
# 11.2 AVERAGE salary per department:
# +----------+------------------+
# |department|        avg_salary|
# +----------+------------------+
# |     Sales|           68000.0|
# |        HR|57666.666666666664|
# |   Finance|           75750.0|
# | Marketing| 83333.33333333333|
# |        IT|63666.666666666664|
# |Operations|           62500.0|
# +----------+------------------+

# %%
#13. Max Aggregation Only
print("\n11.3 MAX salary per department:")
df.groupBy("department").agg(spark_max("salary").alias("max_salary")).show()
# Out:
# 11.3 MAX salary per department:
# +----------+----------+
# |department|max_salary|
# +----------+----------+
# |     Sales|     87000|
# |        HR|     78000|
# |   Finance|     92000|
# | Marketing|    115000|
# |        IT|    125000|
# |Operations|     74000|
# +----------+----------+

# %%
#14. Min Aggregation Only
print("\n11.4 MIN salary per department:")
df.groupBy("department").agg(spark_min("salary").alias("min_salary")).show()
# Out:
# 11.4 MIN salary per department:
# +----------+----------+
# |department|min_salary|
# +----------+----------+
# |     Sales|     49000|
# |        HR|     47000|
# |   Finance|     62000|
# | Marketing|     53000|
# |        IT|     32000|
# |Operations|     51000|
# +----------+----------+

# %%
#15 ALL TOGETHER (Original requirement)
print("\n11.5 ALL aggregations together:")
df.groupBy("department").agg(
    sum("salary").alias("total_salary"),
    avg("salary").alias("avg_salary"),
    spark_max("salary").alias("max_salary"),
    spark_min("salary").alias("min_salary")
).show()
# Out:
# 11.5 ALL aggregations together:
# +----------+------------+------------------+----------+----------+
# |department|total_salary|        avg_salary|max_salary|min_salary|
# +----------+------------+------------------+----------+----------+
# |     Sales|      136000|           68000.0|     87000|     49000|
# |        HR|      173000|57666.666666666664|     78000|     47000|
# |   Finance|      303000|           75750.0|     92000|     62000|
# | Marketing|      250000| 83333.33333333333|    115000|     53000|
# |        IT|      382000|63666.666666666664|    125000|     32000|
# |Operations|      125000|           62500.0|     74000|     51000|
# +----------+------------+------------------+----------+----------+

# %%
#16 Total Salary by Department and Role
print("\n12.1 Total salary by department and role:")
df.groupBy("department", "role").agg(sum("salary").alias("total_salary")).show()
# Out:
# 12.1 Total salary by department and role:
# +----------+--------------+------------+
# |department|          role|total_salary|
# +----------+--------------+------------+
# |   Finance|       Manager|       92000|
# |        IT|     Developer|      174000|
# |        HR|       Manager|       78000|
# |Operations|       Manager|       74000|
# |   Finance|       Analyst|      131000|
# | Marketing|       Manager|       82000|
# |     Sales|     Executive|       49000|
# |        IT|        Tester|       51000|
# |        HR|     Executive|       95000|
# |        IT|     Architect|      125000|
# |        IT|        Intern|       32000|
# | Marketing|       Analyst|       53000|
# |   Finance|Senior Analyst|       80000|
# |Operations|     Executive|       51000|
# | Marketing|      Director|      115000|
# |     Sales|       Manager|       87000|
# +----------+--------------+------------+

# %%
#17 Average Salary by Department and Role
print("\n12.2 Average salary by department and role:")
df.groupBy("department", "role").agg(avg("salary").alias("avg_salary")).show()
# Out:
# 12.2 Average salary by department and role:
# +----------+--------------+----------+
# |department|          role|avg_salary|
# +----------+--------------+----------+
# |   Finance|       Manager|   92000.0|
# |        IT|     Developer|   58000.0|
# |        HR|       Manager|   78000.0|
# |Operations|       Manager|   74000.0|
# |   Finance|       Analyst|   65500.0|
# | Marketing|       Manager|   82000.0|
# |     Sales|     Executive|   49000.0|
# |        IT|        Tester|   51000.0|
# |        HR|     Executive|   47500.0|
# |        IT|     Architect|  125000.0|
# |        IT|        Intern|   32000.0|
# | Marketing|       Analyst|   53000.0|
# |   Finance|Senior Analyst|   80000.0|
# |Operations|     Executive|   51000.0|
# | Marketing|      Director|  115000.0|
# |     Sales|       Manager|   87000.0|
# +----------+--------------+----------+

# %%
#18 Employee Count by Department and Role
print("\n12.3 Employee count by department and role:")
df.groupBy("department", "role").agg(count("*").alias("employee_count")).show()
# Out:
# 12.3 Employee count by department and role:
# +----------+--------------+--------------+
# |department|          role|employee_count|
# +----------+--------------+--------------+
# |   Finance|       Manager|             1|
# |        IT|     Developer|             3|
# |        HR|       Manager|             1|
# |Operations|       Manager|             1|
# |   Finance|       Analyst|             2|
# | Marketing|       Manager|             1|
# |     Sales|     Executive|             1|
# |        IT|        Tester|             1|
# |        HR|     Executive|             2|
# |        IT|     Architect|             1|
# |        IT|        Intern|             1|
# | Marketing|       Analyst|             1|
# |   Finance|Senior Analyst|             1|
# |Operations|     Executive|             1|
# | Marketing|      Director|             1|
# |     Sales|       Manager|             1|
# +----------+--------------+--------------+

# %%
# 19 Additional Operations

print("\n13. Distinct roles count by department:")
df.groupBy("department").agg(countDistinct("role").alias("distinct_roles")).show()
# Out:
# 13. Distinct roles count by department:
# +----------+--------------+
# |department|distinct_roles|
# +----------+--------------+
# |     Sales|             2|
# |        HR|             2|
# |   Finance|             3|
# | Marketing|             3|
# |        IT|             4|
# |Operations|             2|
# +----------+--------------+

# %%
#15 Find the top 3 departments with the highest total salary.
print("\n14. Top 3 departments by total salary:")
df.groupBy("department").agg(sum("salary").alias("total_salary")) \
  .orderBy("total_salary", ascending=False) \
  .limit(3) \
  .show()

print("\nAssignment completed successfully before 12:00 a.m!")
spark.stop()
# Out:
# 14. Top 3 departments by total salary:
# +----------+------------+
# |department|total_salary|
# +----------+------------+
# |        IT|      382000|
# |   Finance|      303000|
# | Marketing|      250000|
# +----------+------------+
#
#
# Assignment completed successfully before 12:00 a.m!
